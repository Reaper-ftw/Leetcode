# %% [markdown]
# <a href="https://colab.research.google.com/github/Reaper-ftw/Leetcode/blob/main/imp_Question_Dsa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from heapq import heappush,heappop
import math
##Function defination
##get_dist is to give the euclidean distance
def get_dist(x,y):
    return math.sqrt(x**2 + y**2)

def kClosest(points,k):
    min_heap=[]
    n=len(points)
    for i in range(n):
        x= points[i][0]
        y= points[i][1]

        ## to insert the element inside the min_heap

        heappush(min_heap,(get_dist(x,y), points[i]))

    result =[]

    for i in range(k):
        ## to delete the element from the minheap

        result.append(heappop(min_heap)[1])
    return result

## Driver code
points =[[3,3],[5,-1],[-2,4]]

k=2
 ## function calling

result = kClosest(points,k)

print("K closest points to the origin is ",result)
# Out:
# K closest points to the origin is  [[3, 3], [-2, 4]]
