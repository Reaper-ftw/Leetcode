# %% [markdown]
# <a href="https://colab.research.google.com/github/Reaper-ftw/Leetcode/blob/main/recursion_concept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def findfactorial(n):
  if n==0 or n==1:
    return 1
  else:
    return n*findfactorial(n-1)







#Driver code

n  =5
result =findfactorial(n)

print("factorial of number is :",result)
# Out:
# factorial of number is : 120
